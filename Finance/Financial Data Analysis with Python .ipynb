# %% [markdown]
# # Finance and Trading Concepts Showcase using Python

# %% [markdown]
# Welcome to this Jupyter Notebook dedicated to showcasing the application of Python in the field of finance and various trading concepts. In this notebook, we will explore how Python can be used to analyze financial data, develop trading strategies, and implement them using programming.
#
# Python has become increasingly popular in the finance industry due to its versatility, extensive libraries, and ease of use. It provides powerful tools for data manipulation, statistical analysis, machine learning, and visualization, making it an excellent choice for finance professionals and traders.
#
# Throughout this notebook, I cover a range of topics related to finance and trading, leveraging Python to perform tasks such as:
#
# 1. Data Analysis: We will utilize Python's data manipulation libraries, such as Pandas, to explore and analyze financial datasets. We can gain insights, preprocess data, and calculate various financial indicators.
#
# 2. Trading Strategies: We will delve into different trading concepts, including technical analysis, momentum strategies, mean reversion, and more. Python will enable us to implement and backtest these strategies using historical data.
#
# 3. Algorithmic Trading: We will explore algorithmic trading techniques and learn how to execute trades automatically based on predefined rules. Python's libraries, such as Backtrader or Zipline, will facilitate the development and testing of algorithmic trading systems.
#
# 4. Data Visualization: Python provides excellent visualization libraries, such as Matplotlib and Seaborn, which allow us to create insightful charts and graphs to visually represent financial data and trading results.
#
# Whether you are an aspiring trader, financial analyst, or someone interested in exploring the intersection of finance and programming, this notebook will serve as a valuable resource for showcasing the application of Python in finance and trading.
#
# Let's dive into the exciting world of finance and trading concepts, harnessing the power of Python!

# %%
import pandas as pd
import yfinance as yf

# %%
start = '2014-10-01'
end = '2023-01-01'

# %%
symbol = 'BA'

# %%
# Downloand the data for the symbol BA from yahoo finance.
# Create a data frame using the pandas 
df = yf.download(symbol, start, end)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-10-01  127.370003  127.370003  124.309998  124.669998  108.406662
# 2014-10-02  124.400002  125.550003  123.839996  124.169998  107.971893
# 2014-10-03  124.660004  126.870003  124.660004  126.360001  109.876205
# 2014-10-06  127.089996  127.190002  125.379997  126.260002  109.789261
# 2014-10-07  125.519997  125.519997  123.290001  123.320000  107.232780
# ...                ...         ...         ...         ...         ...
# 2022-12-23  188.250000  189.429993  184.720001  189.059998  189.059998
# 2022-12-27  189.580002  192.440002  187.619995  189.399994  189.399994
# 2022-12-28  189.320007  191.320007  187.429993  188.380005  188.380005
# 2022-12-29  189.000000  190.250000  186.190002  188.910004  188.910004
# 2022-12-30  187.500000  190.649994  187.039993  190.490005  190.490005
#
#              Volume
# Date
# 2014-10-01  5265200
# 2014-10-02  3204500
# 2014-10-03  3075900
# 2014-10-06  2681000
# 2014-10-07  3554900
# ...             ...
# 2022-12-23  3983600
# 2022-12-27  5014800
# 2022-12-28  4426300
# 2022-12-29  4518900
# 2022-12-30  4007400
#
# [2078 rows x 6 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2078 entries, 2014-10-01 to 2022-12-30
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2078 non-null   float64
#  1   High       2078 non-null   float64
#  2   Low        2078 non-null   float64
#  3   Close      2078 non-null   float64
#  4   Adj Close  2078 non-null   float64
#  5   Volume     2078 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 113.6 KB

# %% [markdown]
# Now download the data for the following stocks using the yahoo finance and create a data frame of the stocks using pandas.
#
# Ticker Symbols:
# * BA: Boeing (US Stock)
# * MSFTL: Microsoft Corp (US Stock)
# * ^DJI: Dow Jones Industrial Average(US Stock Index)
# * EURUSD=X: Exchange Rate for Currency Pair EUR/USD (Forex)
# * GC=F: Gold Price (Precious Metal / Commodity)
# * BTC-USD: Bitcoin in USD (Cryptocurrency)

# %%
symbol = ["BA", "MSFT", "^DJI", "EURUSD=X", "GC=F", "BTC-USD"]

# %%
df = yf.download(symbol, start, end)
df
# Out:
# [*********************100%***********************]  6 of 6 completed
#              Adj Close                                                   \
#                     BA       BTC-USD  EURUSD=X         GC=F        MSFT
# Date
# 2014-10-01  108.406662    383.614990  1.262834  1214.599976   39.623665
# 2014-10-02  107.971901    375.071991  1.262419  1214.199951   39.502796
# 2014-10-03  109.876213    359.511993  1.267058  1192.199951   39.787674
# 2014-10-04         NaN    328.865997       NaN          NaN         NaN
# 2014-10-05         NaN    320.510010       NaN          NaN         NaN
# ...                ...           ...       ...          ...         ...
# 2022-12-27  189.399994  16717.173828  1.064022  1814.800049  235.852386
# 2022-12-28  188.380005  16552.572266  1.063717  1807.900024  233.433731
# 2022-12-29  188.910004  16642.341797  1.062925  1819.500000  239.883453
# 2022-12-30  190.490005  16602.585938  1.066075  1819.699951  238.699020
# 2022-12-31         NaN  16547.496094       NaN          NaN         NaN
#
#                                Close                                       \
#                     ^DJI          BA       BTC-USD  EURUSD=X         GC=F
# Date
# 2014-10-01  16804.710938  124.669998    383.614990  1.262834  1214.599976
# 2014-10-02  16801.050781  124.169998    375.071991  1.262419  1214.199951
# 2014-10-03  17009.689453  126.360001    359.511993  1.267058  1192.199951
# 2014-10-04           NaN         NaN    328.865997       NaN          NaN
# 2014-10-05           NaN         NaN    320.510010       NaN          NaN
# ...                  ...         ...           ...       ...          ...
# 2022-12-27  33241.558594  189.399994  16717.173828  1.064022  1814.800049
# 2022-12-28  32875.710938  188.380005  16552.572266  1.063717  1807.900024
# 2022-12-29  33220.800781  188.910004  16642.341797  1.062925  1819.500000
# 2022-12-30  33147.250000  190.490005  16602.585938  1.066075  1819.699951
# 2022-12-31           NaN         NaN  16547.496094       NaN          NaN
#
#             ...      Open                                            Volume  \
#             ...  EURUSD=X         GC=F        MSFT          ^DJI         BA
# Date        ...
# 2014-10-01  ...  1.262913  1207.699951   46.270000  17040.460938  5265200.0
# 2014-10-02  ...  1.262499  1215.300049   45.830002  16808.269531  3204500.0
# 2014-10-03  ...  1.266994  1212.400024   45.980000  16802.199219  3075900.0
# 2014-10-04  ...       NaN          NaN         NaN           NaN        NaN
# 2014-10-05  ...       NaN          NaN         NaN           NaN        NaN
# ...         ...       ...          ...         ...           ...        ...
# 2022-12-27  ...  1.064022  1803.400024  238.699997  33224.230469  5014800.0
# 2022-12-28  ...  1.063717  1803.199951  236.889999  33264.761719  4426300.0
# 2022-12-29  ...  1.062925  1805.800049  235.649994  33021.429688  4518900.0
# 2022-12-30  ...  1.066075  1817.000000  238.210007  33121.609375  4007400.0
# 2022-12-31  ...       NaN          NaN         NaN           NaN        NaN
#
#
#                 BTC-USD EURUSD=X   GC=F        MSFT         ^DJI
# Date
# 2014-10-01     26229400      0.0  178.0  38088400.0  104240000.0
# 2014-10-02     21777700      0.0  176.0  25119400.0   75490000.0
# 2014-10-03     30901200      0.0  499.0  32453200.0   87940000.0
# 2014-10-04     47236500      NaN    NaN         NaN          NaN
# 2014-10-05     83308096      NaN    NaN         NaN          NaN
# ...                 ...      ...    ...         ...          ...
# 2022-12-27  15748580239      0.0   69.0  16688600.0  246010000.0
# 2022-12-28  17005713920      0.0  434.0  17457100.0  252260000.0
# 2022-12-29  14472237479      0.0  277.0  19770700.0  243060000.0
# 2022-12-30  15929162910      0.0   95.0  21938500.0  295500000.0
# 2022-12-31  11239186456      NaN    NaN         NaN          NaN
#
# [3014 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3014 entries, 2014-10-01 to 2022-12-31
# Freq: D
# Data columns (total 36 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   (Adj Close, BA)        2078 non-null   float64
#  1   (Adj Close, BTC-USD)   3014 non-null   float64
#  2   (Adj Close, EURUSD=X)  2150 non-null   float64
#  3   (Adj Close, GC=F)      2076 non-null   float64
#  4   (Adj Close, MSFT)      2078 non-null   float64
#  5   (Adj Close, ^DJI)      2078 non-null   float64
#  6   (Close, BA)            2078 non-null   float64
#  7   (Close, BTC-USD)       3014 non-null   float64
#  8   (Close, EURUSD=X)      2150 non-null   float64
#  9   (Close, GC=F)          2076 non-null   float64
#  10  (Close, MSFT)          2078 non-null   float64
#  11  (Close, ^DJI)          2078 non-null   float64
#  12  (High, BA)             2078 non-null   float64
#  13  (High, BTC-USD)        3014 non-null   float64
#  14  (High, EURUSD=X)       2150 non-null   float64
#  15  (High, GC=F)           2076 non-null   float64
#  16  (High, MSFT)           2078 non-null   float64
#  17  (High, ^DJI)           2078 non-null   float64
#  18  (Low, BA)              2078 non-null   float64
#  19  (Low, BTC-USD)         3014 non-null   float64
#  20  (Low, EURUSD=X)        2150 non-null   float64
#  21  (Low, GC=F)            2076 non-null   float64
#  22  (Low, MSFT)            2078 non-null   float64
#  23  (Low, ^DJI)            2078 non-null   float64
#  24  (Open, BA)             2078 non-null   float64
#  25  (Open, BTC-USD)        3014 non-null   float64
#  26  (Open, EURUSD=X)       2150 non-null   float64
#  27  (Open, GC=F)           2076 non-null   float64
#  28  (Open, MSFT)           2078 non-null   float64
#  29  (Open, ^DJI)           2078 non-null   float64
#  30  (Volume, BA)           2078 non-null   float64
#  31  (Volume, BTC-USD)      3014 non-null   int64
#  32  (Volume, EURUSD=X)     2150 non-null   float64
#  33  (Volume, GC=F)         2076 non-null   float64
#  34  (Volume, MSFT)         2078 non-null   float64
#  35  (Volume, ^DJI)         2078 non-null   float64
# dtypes: float64(35), int64(1)
# memory usage: 871.2 KB

# %% [markdown]
# ## Initial Inspection and visualization

# %%
df.High
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01 127.3700   391.3790    1.2640 1217.8000  46.5300 17041.1602
# 2014-10-02 125.5500   385.4970    1.2691 1219.5000  46.1000 16857.2500
# 2014-10-03 126.8700   377.6950    1.2670 1212.4000  46.3000 17027.8398
# 2014-10-04      NaN   364.4870       NaN       NaN      NaN        NaN
# 2014-10-05      NaN   341.8010       NaN       NaN      NaN        NaN
# ...             ...        ...       ...       ...      ...        ...
# 2022-12-27 192.4400 16959.8457    1.0669 1826.3000 238.9300 33387.7188
# 2022-12-28 191.3200 16768.1699    1.0674 1807.9000 239.7200 33379.5508
# 2022-12-29 190.2500 16651.7559    1.0670 1819.5000 241.9200 33293.4219
# 2022-12-30 190.6500 16643.4277    1.0698 1822.3000 239.9600 33152.5508
# 2022-12-31      NaN 16628.9863       NaN       NaN      NaN        NaN
#
# [3014 rows x 6 columns]

# %%
df.Close.BA
# Out:
# Date
# 2014-10-01    124.669998
# 2014-10-02    124.169998
# 2014-10-03    126.360001
# 2014-10-04           NaN
# 2014-10-05           NaN
#                  ...
# 2022-12-27    189.399994
# 2022-12-28    188.380005
# 2022-12-29    188.910004
# 2022-12-30    190.490005
# 2022-12-31           NaN
# Freq: D, Name: BA, Length: 3014, dtype: float64

# %%
df.loc["2015-12-01"]
# Out:
# Adj Close  BA          1.324982e+02
#            BTC-USD     3.624880e+02
#            EURUSD=X    1.057295e+00
#            GC=F        1.063800e+03
#            MSFT        4.927584e+01
#            ^DJI        1.788835e+04
# Close      BA          1.477400e+02
#            BTC-USD     3.624880e+02
#            EURUSD=X    1.057295e+00
#            GC=F        1.063800e+03
#            MSFT        5.522000e+01
#            ^DJI        1.788835e+04
# High       BA          1.494000e+02
#            BTC-USD     3.789310e+02
#            EURUSD=X    1.064000e+00
#            GC=F        1.074600e+03
#            MSFT        5.523000e+01
#            ^DJI        1.789550e+04
# Low        BA          1.464700e+02
#            BTC-USD     3.565630e+02
#            EURUSD=X    1.056602e+00
#            GC=F        1.063400e+03
#            MSFT        5.430000e+01
#            ^DJI        1.771972e+04
# Open       BA          1.465400e+02
#            BTC-USD     3.774140e+02
#            EURUSD=X    1.057295e+00
#            GC=F        1.064600e+03
#            MSFT        5.441000e+01
#            ^DJI        1.771972e+04
# Volume     BA          3.444300e+06
#            BTC-USD     6.045220e+07
#            EURUSD=X    0.000000e+00
#            GC=F        3.441000e+03
#            MSFT        3.995280e+07
#            ^DJI        1.038800e+08
# Name: 2015-12-01 00:00:00, dtype: float64

# %%
# The following is to get prices for the ticker symbol BA. 
df.swaplevel(axis="columns")['BA']
# Out:
#              Adj Close       Close        High         Low        Open  \
# Date
# 2014-10-01  108.406662  124.669998  127.370003  124.309998  127.370003
# 2014-10-02  107.971901  124.169998  125.550003  123.839996  124.400002
# 2014-10-03  109.876213  126.360001  126.870003  124.660004  124.660004
# 2014-10-04         NaN         NaN         NaN         NaN         NaN
# 2014-10-05         NaN         NaN         NaN         NaN         NaN
# ...                ...         ...         ...         ...         ...
# 2022-12-27  189.399994  189.399994  192.440002  187.619995  189.580002
# 2022-12-28  188.380005  188.380005  191.320007  187.429993  189.320007
# 2022-12-29  188.910004  188.910004  190.250000  186.190002  189.000000
# 2022-12-30  190.490005  190.490005  190.649994  187.039993  187.500000
# 2022-12-31         NaN         NaN         NaN         NaN         NaN
#
#                Volume
# Date
# 2014-10-01  5265200.0
# 2014-10-02  3204500.0
# 2014-10-03  3075900.0
# 2014-10-04        NaN
# 2014-10-05        NaN
# ...               ...
# 2022-12-27  5014800.0
# 2022-12-28  4426300.0
# 2022-12-29  4518900.0
# 2022-12-30  4007400.0
# 2022-12-31        NaN
#
# [3014 rows x 6 columns]

# %%
close = df.Close

# %%
close
# Out:
#                     BA       BTC-USD  EURUSD=X         GC=F        MSFT  \
# Date
# 2014-10-01  124.669998    383.614990  1.262834  1214.599976   45.900002
# 2014-10-02  124.169998    375.071991  1.262419  1214.199951   45.759998
# 2014-10-03  126.360001    359.511993  1.267058  1192.199951   46.090000
# 2014-10-04         NaN    328.865997       NaN          NaN         NaN
# 2014-10-05         NaN    320.510010       NaN          NaN         NaN
# ...                ...           ...       ...          ...         ...
# 2022-12-27  189.399994  16717.173828  1.064022  1814.800049  236.960007
# 2022-12-28  188.380005  16552.572266  1.063717  1807.900024  234.529999
# 2022-12-29  188.910004  16642.341797  1.062925  1819.500000  241.009995
# 2022-12-30  190.490005  16602.585938  1.066075  1819.699951  239.820007
# 2022-12-31         NaN  16547.496094       NaN          NaN         NaN
#
#                     ^DJI
# Date
# 2014-10-01  16804.710938
# 2014-10-02  16801.050781
# 2014-10-03  17009.689453
# 2014-10-04           NaN
# 2014-10-05           NaN
# ...                  ...
# 2022-12-27  33241.558594
# 2022-12-28  32875.710938
# 2022-12-29  33220.800781
# 2022-12-30  33147.250000
# 2022-12-31           NaN
#
# [3014 rows x 6 columns]

# %%
close.describe()
# Out:
#                 BA       BTC-USD     EURUSD=X         GC=F         MSFT  \
# count  2078.000000   3014.000000  2150.000000  2076.000000  2078.000000
# mean    220.652921  12920.031757     1.132104  1454.775096   139.969235
# std      87.780883  16200.576272     0.057198   272.891327    88.849027
# min      95.010002    178.102997     0.959619  1050.800049    40.290001
# 25%     144.809998    701.194992     1.097809  1230.775024    58.400000
# 50%     189.070000   7149.217773     1.128522  1319.950012   108.005001
# 75%     317.005013  16846.313477     1.175067  1750.450012   217.640003
# max     440.619995  67566.828125     1.282166  2051.500000   343.109985
#
#                ^DJI
# count   2078.000000
# mean   25071.048535
# std     6000.141189
# min    15660.179688
# 25%    18539.471680
# 50%    25127.290039
# 75%    29637.687988
# max    36799.648438

# %%
import matplotlib.pyplot as plt

# %%
# to plot a chart we can use following code. 
close.BA.dropna().plot(figsize = (15, 8), fontsize = 13)
plt.legend(fontsize = 13)
plt.show()

# %%
# To plot a multi variable chart we can simply execute following code. 
close.dropna().plot(figsize=(15, 8), fontsize= 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# The plot above does not give us any useful information. To get useful information out of the ticker symbol which have a different scale, we will explore some methods.

# %% [markdown]
# ## Normalizing Financial Time series to a Base value

# %%
close.iloc[0 ,0]
# Out:
# 124.66999816894531

# %% [markdown]
# To normalize the price, here is a one method call normalizing where we divide each close value by initial value. It means that we invested $1 to particular ticker symbol, how much return we should have received.

# %%
close.BA.div(close.iloc[0, 0])
# Out:
# Date
# 2014-10-01    1.000000
# 2014-10-02    0.995989
# 2014-10-03    1.013556
# 2014-10-04         NaN
# 2014-10-05         NaN
#                 ...
# 2022-12-27    1.519211
# 2022-12-28    1.511029
# 2022-12-29    1.515280
# 2022-12-30    1.527954
# 2022-12-31         NaN
# Freq: D, Name: BA, Length: 3014, dtype: float64

# %%
close.BA.div(close.iloc[0, 0]).mul(100)
# Out:
# Date
# 2014-10-01    100.000000
# 2014-10-02     99.598941
# 2014-10-03    101.355581
# 2014-10-04           NaN
# 2014-10-05           NaN
#                  ...
# 2022-12-27    151.921069
# 2022-12-28    151.102918
# 2022-12-29    151.528039
# 2022-12-30    152.795386
# 2022-12-31           NaN
# Freq: D, Name: BA, Length: 3014, dtype: float64

# %%
norm = close.div(close.iloc[0]).mul(100)
norm
# Out:
#                     BA      BTC-USD    EURUSD=X        GC=F        MSFT  \
# Date
# 2014-10-01  100.000000   100.000000  100.000000  100.000000  100.000000
# 2014-10-02   99.598941    97.773028   99.967178   99.967065   99.694982
# 2014-10-03  101.355581    93.716878  100.334500   98.155769  100.413940
# 2014-10-04         NaN    85.728140         NaN         NaN         NaN
# 2014-10-05         NaN    83.549918         NaN         NaN         NaN
# ...                ...          ...         ...         ...         ...
# 2022-12-27  151.921069  4357.799944   84.256721  149.415452  516.252721
# 2022-12-28  151.102918  4314.891933   84.232527  148.847362  510.958586
# 2022-12-29  151.528039  4338.292877   84.169847  149.802407  525.076223
# 2022-12-30  152.795386  4327.929398   84.419303  149.818869  522.483659
# 2022-12-31         NaN  4313.568686         NaN         NaN         NaN
#
#                   ^DJI
# Date
# 2014-10-01  100.000000
# 2014-10-02   99.978219
# 2014-10-03  101.219768
# 2014-10-04         NaN
# 2014-10-05         NaN
# ...                ...
# 2022-12-27  197.810951
# 2022-12-28  195.633897
# 2022-12-29  197.687428
# 2022-12-30  197.249748
# 2022-12-31         NaN
#
# [3014 rows x 6 columns]

# %%
norm.dropna().plot(figsize=(15, 8), fontsize= 13, logy= False)
plt.legend(fontsize = 13)
plt.show()

# %%
norm.dropna().plot(figsize=(15, 8), fontsize= 13, logy= True)
plt.legend(fontsize = 13)
plt.show()

# %%
msft = yf.download("MSFT", "2014-10-01", "2023-07-08")
msft
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-10-01   46.270000   46.529999   45.849998   45.900002   39.623661
# 2014-10-02   45.830002   46.099998   45.639999   45.759998   39.502815
# 2014-10-03   45.980000   46.299999   45.610001   46.090000   39.787682
# 2014-10-06   46.119999   46.299999   45.919998   46.090000   39.787682
# 2014-10-07   45.860001   45.930000   45.419998   45.529999   39.304249
# ...                ...         ...         ...         ...         ...
# 2023-06-30  337.750000  342.730011  337.200012  340.540009  340.540009
# 2023-07-03  339.190002  340.899994  336.570007  337.989990  337.989990
# 2023-07-05  335.089996  341.649994  334.730011  338.149994  338.149994
# 2023-07-06  337.299988  342.989990  335.500000  341.269989  341.269989
# 2023-07-07  339.320007  341.790009  337.000000  337.220001  337.220001
#
#               Volume
# Date
# 2014-10-01  38088400
# 2014-10-02  25119400
# 2014-10-03  32453200
# 2014-10-06  20604000
# 2014-10-07  25723700
# ...              ...
# 2023-06-30  26823800
# 2023-07-03  12508700
# 2023-07-05  18172400
# 2023-07-06  28161200
# 2023-07-07  21185300
#
# [2206 rows x 6 columns]

# %%
msft['Close'].diff()
# Out:
# Date
# 2014-10-01         NaN
# 2014-10-02   -0.140003
# 2014-10-03    0.330002
# 2014-10-06    0.000000
# 2014-10-07   -0.560001
#                 ...
# 2023-06-30    5.490021
# 2023-07-03   -2.550018
# 2023-07-05    0.160004
# 2023-07-06    3.119995
# 2023-07-07   -4.049988
# Name: Close, Length: 2206, dtype: float64

# %%
msft["P_diff"] = msft.Close.diff()

# %%
msft
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-10-01   46.270000   46.529999   45.849998   45.900002   39.623661
# 2014-10-02   45.830002   46.099998   45.639999   45.759998   39.502815
# 2014-10-03   45.980000   46.299999   45.610001   46.090000   39.787682
# 2014-10-06   46.119999   46.299999   45.919998   46.090000   39.787682
# 2014-10-07   45.860001   45.930000   45.419998   45.529999   39.304249
# ...                ...         ...         ...         ...         ...
# 2023-06-30  337.750000  342.730011  337.200012  340.540009  340.540009
# 2023-07-03  339.190002  340.899994  336.570007  337.989990  337.989990
# 2023-07-05  335.089996  341.649994  334.730011  338.149994  338.149994
# 2023-07-06  337.299988  342.989990  335.500000  341.269989  341.269989
# 2023-07-07  339.320007  341.790009  337.000000  337.220001  337.220001
#
#               Volume    P_diff
# Date
# 2014-10-01  38088400       NaN
# 2014-10-02  25119400 -0.140003
# 2014-10-03  32453200  0.330002
# 2014-10-06  20604000  0.000000
# 2014-10-07  25723700 -0.560001
# ...              ...       ...
# 2023-06-30  26823800  5.490021
# 2023-07-03  12508700 -2.550018
# 2023-07-05  18172400  0.160004
# 2023-07-06  28161200  3.119995
# 2023-07-07  21185300 -4.049988
#
# [2206 rows x 7 columns]

# %%
msft["Percent_change"] = msft.P_diff / msft['Close'] * 100
msft
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2014-10-01   46.270000   46.529999   45.849998   45.900002   39.623661
# 2014-10-02   45.830002   46.099998   45.639999   45.759998   39.502815
# 2014-10-03   45.980000   46.299999   45.610001   46.090000   39.787682
# 2014-10-06   46.119999   46.299999   45.919998   46.090000   39.787682
# 2014-10-07   45.860001   45.930000   45.419998   45.529999   39.304249
# ...                ...         ...         ...         ...         ...
# 2023-06-30  337.750000  342.730011  337.200012  340.540009  340.540009
# 2023-07-03  339.190002  340.899994  336.570007  337.989990  337.989990
# 2023-07-05  335.089996  341.649994  334.730011  338.149994  338.149994
# 2023-07-06  337.299988  342.989990  335.500000  341.269989  341.269989
# 2023-07-07  339.320007  341.790009  337.000000  337.220001  337.220001
#
#               Volume    P_diff  Percent_change
# Date
# 2014-10-01  38088400       NaN             NaN
# 2014-10-02  25119400 -0.140003       -0.305951
# 2014-10-03  32453200  0.330002        0.715994
# 2014-10-06  20604000  0.000000        0.000000
# 2014-10-07  25723700 -0.560001       -1.229961
# ...              ...       ...             ...
# 2023-06-30  26823800  5.490021        1.612151
# 2023-07-03  12508700 -2.550018       -0.754466
# 2023-07-05  18172400  0.160004        0.047317
# 2023-07-06  28161200  3.119995        0.914231
# 2023-07-07  21185300 -4.049988       -1.200993
#
# [2206 rows x 8 columns]

# %%
msft[['Close', 'Percent_change']]
# Out:
#                  Close  Percent_change
# Date
# 2014-10-01   45.900002             NaN
# 2014-10-02   45.759998       -0.305951
# 2014-10-03   46.090000        0.715994
# 2014-10-06   46.090000        0.000000
# 2014-10-07   45.529999       -1.229961
# ...                ...             ...
# 2023-06-30  340.540009        1.612151
# 2023-07-03  337.989990       -0.754466
# 2023-07-05  338.149994        0.047317
# 2023-07-06  341.269989        0.914231
# 2023-07-07  337.220001       -1.200993
#
# [2206 rows x 2 columns]

# %%
msft.Percent_change.plot(figsize=(15, 8), fontsize= 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# General Rule in Finance/Investing: Higher Risk must be rewarded with higher Returns

# %%
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn-v0_8")

# %%
msft.Close.plot(figsize=(15, 8), fontsize= 13)
plt.legend(fontsize = 13)
plt.show()

# %% [markdown]
# To understand performance of the stock there are a few methods that investors utilize.
# * Reward: positive returns
# * Risk: Volatility of Returns

# %%
msft[["Close", "Percent_change"]].describe()
# Out:
#           Close  Percent_change
# count 2206.0000       2205.0000
# mean   148.4392          0.0749
# std     93.1254          1.7652
# min     40.2900        -17.2870
# 25%     61.1825         -0.7094
# 50%    112.8100          0.0732
# 75%    237.6775          0.9856
# max    348.1000         12.4473

# %%
BTC = df.swaplevel(axis="columns")['BTC-USD']

# %%
BTC
# Out:
#             Adj Close      Close       High        Low       Open       Volume
# Date
# 2014-10-01   383.6150   383.6150   391.3790   380.7800   387.4270     26229400
# 2014-10-02   375.0720   375.0720   385.4970   372.9460   383.9880     21777700
# 2014-10-03   359.5120   359.5120   377.6950   357.8590   375.1810     30901200
# 2014-10-04   328.8660   328.8660   364.4870   325.8860   359.8920     47236500
# 2014-10-05   320.5100   320.5100   341.8010   289.2960   328.9160     83308096
# ...               ...        ...        ...        ...        ...          ...
# 2022-12-27 16717.1738 16717.1738 16959.8457 16642.0723 16919.2910  15748580239
# 2022-12-28 16552.5723 16552.5723 16768.1699 16497.5566 16716.4004  17005713920
# 2022-12-29 16642.3418 16642.3418 16651.7559 16508.6836 16552.3223  14472237479
# 2022-12-30 16602.5859 16602.5859 16643.4277 16408.4746 16641.3301  15929162910
# 2022-12-31 16547.4961 16547.4961 16628.9863 16517.5195 16603.6738  11239186456
#
# [3014 rows x 6 columns]

# %%
BTC['Daily_Returns'] = BTC.Close.diff() / BTC.Close * 100
BTC[["Close", "Daily_Returns"]]
# Out:
#                 Close  Daily_Returns
# Date
# 2014-10-01   383.6150            NaN
# 2014-10-02   375.0720        -2.2777
# 2014-10-03   359.5120        -4.3281
# 2014-10-04   328.8660        -9.3187
# 2014-10-05   320.5100        -2.6071
# ...               ...            ...
# 2022-12-27 16717.1738        -1.2121
# 2022-12-28 16552.5723        -0.9944
# 2022-12-29 16642.3418         0.5394
# 2022-12-30 16602.5859        -0.2395
# 2022-12-31 16547.4961        -0.3329
#
# [3014 rows x 2 columns]

# %%
BTC[["Close", "Daily_Returns"]].describe()
# Out:
#            Close  Daily_Returns
# count  3014.0000      3013.0000
# mean  12920.0318         0.0494
# std   16200.5763         3.9424
# min     178.1030       -59.1585
# 25%     701.1950        -1.3706
# 50%    7149.2178         0.1775
# 75%   16846.3135         1.7441
# max   67566.8281        20.1579

# %%
BTC.Daily_Returns.idxmin()
# Out:
# Timestamp('2020-03-12 00:00:00', freq='D')

# %%
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use("seaborn")

msft = yf.download("MSFT", "2013-01-01", "2023-07-10")
# Out:
# C:\Users\sawan\AppData\Local\Temp\ipykernel_23932\3008172198.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")
# [*********************100%***********************]  1 of 1 completed

# %%
# This shows how much we could have make for every $1 invested in the stock. 
multiple = (msft.Close[-1] / msft.Close[0])
multiple
# Out:
# 12.209268319126625

# %%
# The return does not give a full story unless there is time period information. 
start = msft.index[0]
end = msft.index[-1]
years_invested = (end - start).days / 365.25
years_invested
# Out:
# 10.507871321013004

# %%
cagr = multiple ** (1 / years_invested) - 1
cagr
# Out:
# 0.26886881819283825
